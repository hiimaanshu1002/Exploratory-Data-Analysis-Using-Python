# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# **Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Exercise 1
#
# **Follow along with these steps:**<br>
# **Create a figure object called fig using plt.figure()**<br>
# **Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.**<br>
# **Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title('title')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.plot(x,y)
plt.show()

# %% [markdown]
# ## Exercise 2
# **Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,0.2,0.2])

# %% [markdown]
# **Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
ax1.plot(x,y)
ax2.plot(x,y)
fig

# %% [markdown]
# ## Exercise 3
#
# **Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,0.4,0.4])

# %% [markdown]
# **Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
ax1.plot(x,label="linear 1x")
ax1.plot(y,label="linear 2x")
ax1.plot(z,label="quadratic")
ax1.set_xlabel('x')
ax1.set_ylabel('z')
ax1.legend()

ax2.plot(x,label = 'linear 1x')
ax2.plot(y,label = 'linear 2x')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.legend()
ax2.set_title('zoom')
ax2.set_xlim(20.0,22.0)
ax2.set_ylim(30,50)
fig

# %% [markdown]
# ## Exercise 4
#
# **Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig, ax = plt.subplots(1,2)
plt.show()

# %% [markdown]
# **Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
ax[0].plot(x,y,'b:',lw = 3)
ax[1].plot(x,z,'r--',lw=0.5)
fig

# %% [markdown]
# **See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
fig, ax = plt.subplots(1,2,figsize = (20,5))
ax[0].plot(x,y,'b--')
ax[1].plot(x,z,'r-')

# %% [markdown]
# # Great Job!
